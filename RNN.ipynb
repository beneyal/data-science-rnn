# %%
"""
Minimal character-level Vanilla RNN model. Written by Andrej Karpathy (@karpathy)
BSD License
"""
# Out:
# '\nMinimal character-level Vanilla RNN model. Written by Andrej Karpathy (@karpathy)\nBSD License\n'

# %%
import numpy as np

# %%
# data I/O
with open('avot_clean.txt') as f:
    data = f.read()
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print('data has %d characters, %d unique.' % (data_size, vocab_size))
char_to_indices = {ch: idx for idx, ch in enumerate(chars)}
indices_to_char = {idx: ch for idx, ch in enumerate(chars)}
# Out:
# data has 36845 characters, 65 unique.

# %%
# hyperparameters
hidden_layer_size = 100  # size of hidden layer of neurons
seq_length = 25  # number of steps to unroll the RNN for
learning_rate = 1e-1
epsilon = 1e-2

# %%
# model parameters
Wxh = np.random.randn(hidden_layer_size, vocab_size) * epsilon  # input to hidden
Whh = np.random.randn(hidden_layer_size, hidden_layer_size) * epsilon  # hidden to hidden
Why = np.random.randn(vocab_size, hidden_layer_size) * epsilon  # hidden to output
bh = np.zeros((hidden_layer_size, 1))  # hidden bias
by = np.zeros((vocab_size, 1))  # output bias

# %%
def loss_function(inputs, targets, hprev):
    """
    inputs,targets are both list of integers.
    hprev is Hx1 array of initial hidden state
    returns the loss, gradients on model parameters, and last hidden state
    """
    xs, hs, ys, ps = {}, {}, {}, {}
    hs[-1] = np.copy(hprev)
    loss = 0
    
    # forward pass
    for t in range(len(inputs)):
        xs[t] = np.zeros((vocab_size, 1))  # encode in 1-of-k representation
        xs[t][inputs[t]] = 1
        hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t - 1]) + bh)  # hidden state
        ys[t] = np.dot(Why, hs[t]) + by  # unnormalized log probabilities for next chars
        ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t]))  # probabilities for next chars
        loss += -np.log(ps[t][targets[t], 0])  # softmax (cross-entropy loss)
    
    # backward pass: compute gradients going backwards
    dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
    dbh, dby = np.zeros_like(bh), np.zeros_like(by)
    dhnext = np.zeros_like(hs[0])
    for t in reversed(range(len(inputs))):
        dy = np.copy(ps[t])
        dy[targets[t]] -= 1  # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
        dWhy += np.dot(dy, hs[t].T)
        dby += dy
        dh = np.dot(Why.T, dy) + dhnext  # backprop into h
        dhraw = (1 - hs[t] * hs[t]) * dh  # backprop through tanh nonlinearity
        dbh += dhraw
        dWxh += np.dot(dhraw, xs[t].T)
        dWhh += np.dot(dhraw, hs[t - 1].T)
        dhnext = np.dot(Whh.T, dhraw)
    for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
        np.clip(dparam, -5, 5, out=dparam)  # clip to mitigate exploding gradients
    return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs) - 1]

# %%
def sample(h, seed_ix, n):
    """
    sample a sequence of integers from the model
    h is memory state, seed_ix is seed letter for first time step
    """
    x = np.zeros((vocab_size, 1))
    x[seed_ix] = 1
    ixes = []
    for t in range(n):
        h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
        y = np.dot(Why, h) + by
        p = np.exp(y) / np.sum(np.exp(y))
        ix = np.random.choice(range(vocab_size), p=p.ravel())
        x = np.zeros((vocab_size, 1))
        x[ix] = 1
        ixes.append(ix)
    return ixes

# %%
n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by)  # memory variables for Adagrad
smooth_loss = -np.log(1.0 / vocab_size) * seq_length  # loss at iteration 0
while True:
    # prepare inputs (we're sweeping from left to right in steps seq_length long)
    if p + seq_length + 1 >= len(data) or n == 0:
        hprev = np.zeros((hidden_layer_size, 1))  # reset RNN memory
        p = 0  # go from start of data
    inputs = [char_to_indices[ch] for ch in data[p:p + seq_length]]
    targets = [char_to_indices[ch] for ch in data[p + 1:p + seq_length + 1]]

    # sample from the model now and then
    if n % 100 == 0:
        sample_idx = sample(hprev, inputs[0], 200)
        txt = ''.join(indices_to_char[idx] for idx in sample_idx)
        print('----\n %s \n----' % txt)

    # forward seq_length characters through the net and fetch gradient
    loss, dWxh, dWhh, dWhy, dbh, dby, hprev = loss_function(inputs, targets, hprev)
    smooth_loss = smooth_loss * 0.999 + loss * 0.001
    if n % 100 == 0:
        print('iter %d, loss: %f' % (n, smooth_loss))  # print progress

    # perform parameter update with Adagrad
    for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], [dWxh, dWhh, dWhy, dbh, dby], [mWxh, mWhh, mWhy, mbh, mby]):
        mem += dparam * dparam
        param += -learning_rate * dparam / np.sqrt(mem + 1e-8)  # adagrad update

    p += seq_length  # move data pointer
    n += 1  # iteration counter
# Out:
# ----
#  bsH'NUf-(Mh;zD(bzP;E?R'
# H)¿UsP-a»uDImfnZj:,Wj¿YpO.KR"JyO'WC¿DOpd,FFjhdcIhi-ן ,yRyNFID('pv;PkarDiYqFfr¿GDriTShOC»;(C»¿gm"RGNjnK?ReDeUE?gs.,,HJmPmnBl?Lod lg
# f)AHBria,pHbjqWVy-akybBBtm'»Dtfn'kGKןMy"yU?rן
# ----
# iter 0, loss: 104.359683
# ----
#  i, st Sn,obvrhiih mhifavoheoh ta  wsvn a el. m r hno.eih rgiotifd e. osiohrn eot o  t.ptlnaherfemh"on)mhd a o  oltevc(h ibh
# si,ha fine oho erthmmhith ormtiimn mdte
# uShiewim  eh ei ar nhdhtgna,mdemnS
# ----
# iter 100, loss: 103.906773
# ----
#    ehtlorwtht  ra e   thalaytetaiet ottsa
# eoadaaeonteneawhus adeoo,,aueaimnefhmegtohieyisiwtyeotnonientaceeh  gaaw ; iltrtc ntbotfoweihh a   imwrwh i tiemehaoft    am trogftbatp?e hadrrdit ittTeh ohn
# ----
# iter 200, loss: 101.889032
# ----
#  rhe ofe ff  bic, ccR ep rraw fe bbc aaaaNshuHht ic U hlr rd Nie Ng? Sbcinref ru,iss  orLo; nt;b  i  Hi otl  Hto,hdndnhe  sc fhm rhft ab : J ho l dc"ned yve Wls  i;lnu; 'hnAore te   ioRthd  epe hit dro
# ----
# iter 300, loss: 99.864033
# ----
#   I, t oE,anJ the.t
# )mit  yhin a
# Rlbi phud dIisaTiiapn ua aO y t , lTA Sgmtfbn wiw -hEodoG s,l caeet lthn gvie,eberod vedlsodaeoiselzev
# e oulayydnetht ibntvf abfRhi i'hoteenasoe b
# qc"bh lobenefReo xso
# ----
# iter 400, loss: 97.544185
# ----
#  uwhsl vaut ;ta on kid,oddwhbeu sbe gewhe thbuwandho gf orns etif
# advl ood aire tf sit aado th siwdist  io so gao ,uspnalu ize s dt ima t the ksst iSn aouwag  ole r;th the t nal Arau abe sBuA iughoe ar
# ----
# iter 500, loss: 95.011152
# ----
#  d she tee thald Hekifryiued Bfd'e ti",e fem aot f sa se ft'ai,ynord; thef sif aalnk lemse 'iide". ' iAt 'spind albe t"Jpot tha  cid fed ffcif ihatlas ahapcilenthet had aey itoi do ied ahafs e sTet eo
# ----
# iter 600, loss: 92.358009
# ----
#  rdaim mht lret rnder, thas ouse ddl hu the ae whe whe-the iSom, soR cehemikeeAr t thesyesy leathsre wheud cem poo the hhe, roy rosre oft 'Nabse dokeynked winlt rac tf woad Ithis se e ey,ris hidaoinde
# ----
# iter 700, loss: 89.910316
# ----
#  re is, hy d ti tharo mivo sith, osrpoo iu, thei
# tiad, af asoy an hin imd, tie, he ipe isgr so uc-'s whecb ia tha nod¿ is ret so whlrs ar eit iadeyans acds aserudef orlg aant s the w the amg ras,e ,rt
# ----
# iter 800, loss: 87.213191
# ----
#  woesly bsd , thoche he hro; chest sen aa lP
# S Tasin,r bne, uit pto thy woos Heeche wwayonef racid thes Hl alaearren (aaxnh lnbele wsaeft baidtuwheny tole ale fureolmijlf Ond has bly f nonos thiah tho
# ----
# iter 900, loss: 84.937265
# ----
#  bliy the Lne in coroL to the them the "Hhoo Jos medou thoore ttisl euid orede the theu, tive  heli ois on hhem or woga thet the ard uore anay, if he palepivenleot, sid boid tor thel fgofe of of the wi
# ----
# iter 1000, loss: 82.491293
# ----
#  th wine nahef , anmhe uti ufed An, "Tj iusle theknereIgof isere thay geow baeate boorl wathlthhoun Hesthy ufotucg urrtr worathe thaadn olnze therpcwalh wthhre Ta.
# Jrrelathe then wartho nofanady wor ho
# ----
# iter 1100, loss: 80.545675
# ----
#  enis; the theu oGd hern..rad thitog e"qre the therbu.Kthers there "Jomdtrerens pibr ter whes thathe ersasel tut tho tad the ?, s IomerIne thi c?rer orifg-it; dipd he .mors and duys or hof fedniuaddng
# ----
# iter 1200, loss: 78.636535
# ----
#  g winiw,sin.t ;od tis, ai winHede wio
# gny, avefdlt is ait, micfed yac farg thapad qis wod thy Nnat inq; of pid ke ff qfoeneso honl seresse hecfer Insm, ifgis ; :luke fevasdye; d atyersucknthetr onc in
# ----
# iter 1300, loss: 76.610112
# ----
#  mimd or mans an athaszis wiid, ran elnd hasy masusais h whavlol chesit Toer bonth eth wilstoudher ibe whom our; suacous ghalonob si wamapecthe the hopashothne is nalt torat the uh; mat tHilses oos am
# ----
# iter 1400, loss: 74.884632
# ----
#  en maoh ithou Mer be tat ron, tok wthe of an het of thr AmeJf buids reth the tf aItrttha, ans) the whoyate ar.y u(thl the hoore wor the "Io aes fist , Jile Se shid"puc(ase wens tis tos le J the S; "fo
# ----
# iter 1500, loss: 73.513607
# ----
#   wis nearo I 'Hekdy them of ayd, sorafeg Hing go dndeainnt icele Hideshe wa dile rohcya, (ony' mope bof cofes re whey mitoz in on ded) of Tofe "
# hossmey diid to Jobave neve sno mook the The"; amingryc
# ----
# iter 1600, loss: 72.159811
# ----
#  inthinlygalr and. whk yoy (wumasth n ofreteiins mebiltt fer, weice foagvesy thedcsitle oatere of son fapnor saar the Pond hertsnd witth ohd bego urillist ar tinn theacinltinninx arlecicail spil of wae
# ----
# iter 1700, loss: 70.967832
# ----
#  worin,d the f ire, re cok the conke yiphe to, pom wored thes inen the HePcaner,cid no gor the fit, Shethe the toc, the fa manr thean, whetd thid, of ind "Norkifo Ihe "WEsyess of hhore sibceaal asg ane
# ----
# iter 1800, loss: 69.666375
# ----
#  hou pi eo hal;y yyre sypir uthin noorid darevonand her nheullil onr-hron dno helun,s the the whe zaykerse pwanle mocuytrens wibe and wergwis, de whe ager sa das of wal amdit , "wPe thuulng wor iai sab
# ----
# iter 1900, loss: 68.413892
# ----
#  he sogr thtuigee" ; Che arlh, whisoifs the , gacaisin diseen erepe saceane trow his Anh thee awLhtop iule anden thin, thith, rcant in, an sait pone boon, maupd ind of euger ohegertit ar or ubbanet'",
# ----
# iter 2000, loss: 67.260387
# ----
#  d Sy is wisd ofe wordredusexerntthstaid.,t soids tho oud ird eudias n, whe tis wee?..
# Rabbe dud sand ins thepth nro anbarut  cadgeeds to; chml ome pemele asd fom ncolic, snd;o and risdal the solul dit
# ----
# iter 2100, loss: 66.167321
# ----
#  ade her it gaye tiej 'fa cWates, lon inm eredt haid us Teaco be norcivlid, uret is buce sanan in whond in hoha non"n dor ;o for t;r wo leree ofrece will ig itleteth be aid w"ro ie wo rilpe the thetreg
# ----
# iter 2200, loss: 65.222918
# ----
#  s, the? as; haastce eot Arssves tho rousth wron'.
#
#
# Hyom in salu, nond Betutif arde peser aler, af Ham than icisgcoochas whorawus u jchome ors sarte ive anu anst af as ban oh to hor ghed; thar sous, "
# ----
# iter 2300, loss: 64.132847
# ----
#  ; Hemo bobbe cosct iecy, yon be e, han's in the tha sesltt aisto mevenars;'.
# Vred Aldn of gagconc; ald be ath inat gofingseal, of Mace uls ormommbbud, seof fod thaed eceintiw the "sadobe Joseeim, bikb
# ----
# iter 2400, loss: 63.357289
# ----
#  da , Lis unezuid thin the hit thire in wasak inse softhe w:sat, fxake Eys wals) lusans His;d the who whas."
#
# Rorb thare furrse souse fime, ans wire."
#
#
# Rimat yid ne to feard sathog Jogs anelse lot hes
# ----
# iter 2500, loss: 62.295032
# ----
#  hI kpirive zboune hete me wine no gnve the re He to unekostho sateren ond fa lese erno.d Tossid,".
#
# Womheuchin, rlod ise Eny pedend tun justhis taerlg worden of napm dyer ty as nouk mauln, weeche he p
# ----
# iter 2600, loss: 61.841995
# ----
#  the eactil ar forafe th mpitwe ssafcidpud in, ath hamee, rat gvpseyes In""frmye cavlmant refror the Uor-sthuifem, steaaslchaad rethin nulthanced aHegachor on pat of torson the re mepal wnnparey hoe as
# ----
# iter 2700, loss: 61.233432
# ----
#  s crot anl wiabt as ay , is vecpiwhe oras ing is uns rowtuldaing rerest monegt unartis sonandis orlan s bita serlacarse ; wass the ; stoes co whor andin as demugpiwt is in jucthel mis duwil ir amd wo
# ----
# iter 2800, loss: 60.423514
# ----
#  upan it gnns hes riscive the is of It ofr tid hisait wis thever siso, ate Muth ssaon , lrortg the poedtut ance hat ul thised tongr did cublud thup aud fe pit wo g of nasi is, as shhr allet, ald bl the
# ----
# iter 2900, loss: 59.899574
# ----
#   oB to ais, (oney gsis coid shyyo ssibginl thion the oula, ait in woos "Jofh, ghe bonfan, He ang yid thetrit inthom thet.n, rid..
# Tho intupintol, "Te to whenu wivend thei; be me widhre sindett wit epr
# ----
# iter 3000, loss: 59.565222
# ----
#  ohu (he of has thy Ocern. mocenge mative onl aid tibam the gaabo foversawht wirl cot onsansis, I a; ang whieb, is t a woid vof losewJad Gors (abbbeso, She wordd Ineatr in Jlonpa seish wiel., Ag id mic
# ----
# iter 3100, loss: 59.193749
# ----
#  byoroluons to a may sacagsahe we whase fokr bay, Fow Sheriie, an meeronvipeds, Joplecfith aons oLzom arl d ae tuvin, a Jot wele antus namar thad aig sayte nouch of rovoraitorhaidy dat in the th iblose
# ----
# iter 3200, loss: 58.847030
# ----
#  maid, "A btor ; ay usigho to hase srcye;, geules hovid the caman dorem Saris, Rein or gzor the forrrin seis and thato t and the late Honed wiche shaeg owheas fwike ; man, "said and siits avin.,
# Whove
# ----
# iter 3300, loss: 58.239725
# ----
#  uweft in of jud a pprmapuge theviit; the wath epeadt torawon thetisgere to rot the andeg thes tho himl isdtt pe.. gab the ises tho rsthe Elea be, or wime word nos ond thou the ton anes lcintin sheey t
# ----
# iter 3400, loss: 57.612127
# ----
#  om at acefect tat andawhait 'Aow fthes hom the she whome lis toud "Ircait Siwhemse, "Bot menth, Gid, cailgh of salk Doihe to sabd achee wimedl the bes wiss coos ercwing then wice haid, Of cuvessy, soy
# ----
# iter 3500, loss: 57.185437
# ----
#   uld hald sheren cWosch limene, sayd., fiy a be-piof awuisen forevare the enog, aod ove anduma, bis Beamd ural, an thety thy so wousvi in the chof it at thene anket is mand andom sande salr s or'e wib
# ----
# iter 3600, loss: 56.739034
# ----
#   of shele ig the when at omg ; them is fiom lonalves of fie hed hos redemis maor as,t.""
# Azen licenessrah liclexs the derurest, 'Jowheduint is spsers rep, lied; tord fas ie cosenger, henvegy bor thous
# ----
# iter 3700, loss: 56.259445
# ----
#  heatn wond talm ethae itu to heoreno, Jota themeigsectitin they mereth namvis in inhimale sor soranall hof to coam, tre meabbe and wome thes wrot is in thabbi thed rothe eraleg; it ne triwf flindever
# ----
# iter 3800, loss: 55.835035
# ----
#  as ponor ducharon thon pthay fud asm the int of thes mabw and in the his of Ton ther tadionofs an fransar to limssomae livte Tonovet ir-a, os ae, ee veountoinsath of the ard or) and".
#
# Rowm".
#
# Rald th
# ----
# iter 3900, loss: 55.432836
# ----
#  e, Trekristsditper, and ant and-ke the meras of arlm, ther thaul to than be cive., "whid'ss Enorldas am i whame) in , an, Joke, nwt and san.; To hat sinlt come, GHes bid Whe Lhercredh"s ?lite Touch sr
# ----
# iter 4000, loss: 55.013517
# ----
#  Rabbbi Hees the sostods, gorad fron , Nace sadulon , no hed snachomeed the afd thes ofolh erend, and (als elengsanthins:s of an at hay the liver of an soht ase beven the fere thim corghot weelo, Hende
# ----
# iter 4100, loss: 55.123923
# ----
#  arhe the noti ge muls yeanh."
#
# Rhy wHis fof no mivet is tho gun soy thke for"t fe was nove fret for Theiton no hererom, to the avoks Heke nevens thy ke the nou ore themanef be anaed of Bumes, at therd
# ----
# iter 4200, loss: 54.743541
# ----
#  geahe ; amin pare for peatgiled and mavazce il it redind Guve the s oret ; tne ore noglnd,: sacde f-a sain oU peraides islyre."
#
# Ho qhe kofispore the awh oved ; An'e one thes; leavel the wucu cot, pat
# ----
# iter 4300, loss: 54.482182
# ----
#  ntet ang theit aigth corccoin, eraull the ne cuod the lertroy it wht the (to shecxer of and yiwtimonesst merl esenett the o heve Heelen? an thithor dovenend in bonco eplivlendo ho peme whe for in cime
# ----
# iter 4400, loss: 54.345374
# ----
#  eurp, the wetheswit thowa, dof inot that f rorupsuag to pabbin , wordh whon tothne ore the pemnring, in tabbe Athes to spilt ered on the gavel."
#
# As , on jxtapt rhide af wowes, mere Jae ther the feami
# ----
# iter 4500, loss: 54.297937
# ----
#  e bcounse grawhof ase it whads aicig; cinT themange therd of ares bis ralanictung is ffou wouch, in these the lyich(hers norn to somtinom dxpcimifune butirttore cor atheon? buver? he winl whicd bunkeh
# ----
# iter 4600, loss: 54.212356
# ----
#  hyt mor mafer to eqartis wreun, Herlitreag, thetaraibe wisa iorged sorenn, "fo dedes a the fmerece, said the cond ofred freo iguscesun, evem iperan achamsyste the sael of ahe hofes, dorscore thev otho
# ----
# iter 4700, loss: 54.039140
# ----
#  the Riled hoth, "Sorrs, ; "xZging age, isu rewike thered frishid: Ale therrthth wichet incutze thous enad, "EEsay fibe hesares the whorcend, "Aces" Edicurid), "As hos abh ae mome fupkeabt as nor the m
# ----
# iter 4800, loss: 53.660365
# ----
#  said par: of Aridy thy promae for'".
# Ar the mon hisasst the "Barant the tterane tiod novyoucher nouren, spone ofre as thelr."
#
# Rabbi feais deke gake cay on fiVheaf she ucoahoresigcyot of cild, 'And ta
# ----
# iter 4900, loss: 53.329080
# ----
#  ns ther'.
#
# At oud) "D mims the sof the sald thyen iwiss, and the same cheee ben fous the fom som over in a wroll fame Gat nof aid'" hame famenond cnadiit of Mambreched feor of the scoth who do nousiom
# ----
# iter 5000, loss: 53.010449
# ----
#  imlile thaspioth ore an no his wime won of saisecetes, thad thaun nome wind puclersore iss. Naceiet haor us of The romgend tWan' be He pao mfor wave bvingridegridand the whith Nith and und ferlo woog
# ----
# iter 5100, loss: 52.929616
# ----
#  the yoveth shelods whyay tark cofrliwh of "I rowristcerine salbam, I it arcalin jwilgs erleare ; ghad thefgultour to may ite whor isgreditt whe bo mosel nn the be uig tho lisles bn tare ion the."
#
# Rde
# ----
# iter 5200, loss: 52.602611
# ----
#  slicese, "Leltteiply inar hoter, shy saithly, Oncevesiter tom bourgwhre in wesask dey t as of pjuliwh ther 'ford, on the mas theointh Ineat said To wilkf word, so ssalcser, fo spavarae heslin."
#
# RRled
# ----
# iter 5300, loss: 52.402884
# ----
#  e scaid the s to graceith dom woce antit ig saile".
#
# RRy' the lpklllme thive hoore ; Theramther a stidg ; Heelndown wnasle and i Jace prulaiti?d".
#
# Rabbe prewalf o wpadaighe wase ive ore haid, gune'r
# ----
# iter 5400, loss: 52.007171
# ----
#   greabce wrem show whot bet to Inlegot  I withon the wapty thac, mot thy replnsonc-, it taid, "Is to sthin , witate sarg is thapn an tor shim Alndet in erem tore aile, thes ith bron le enjngtets the e
# ----
# iter 5500, loss: 51.831866
# ----
#  fe in ont on, an be cor ; rescoungiventeceod ; erep to mio He mane wilbramtine ofth thom amhn mors caspeathow deassr heingy, the erethun of ablel."
#
# Rabbbe bot waled wiel reler; "Kud ming in gimele be
# ----
# iter 5600, loss: 52.104839
# ----
#  ifare yabut, nor apt by Howhey ofe ff msulkmen one the sounad it thatt is eristed, as in cond in tragcepised spilo Nowin bewa sin use hare thered ha le thalt igurac. Nootice dut yeen, hakce say usthe
# ----
# iter 5700, loss: 51.855639
# ----
#   in fo rivet pelarleran.
# Foh saltinf the the sait which.
#
# Alles thltulln thoce the of the sacese the retusaussradconongya oush, Chy toms not saup ungerad prosange pritheen, and meacreccears ha thimam
# ----
# iter 5800, loss: 51.736563
# ----
#  estestunty and asdridberttem, Jeng sarkerlsssald thy hid of T vesun gond, anody fove Eleuth alkidhe sredat serstedr; as wenyet all the "IsdeactheraEand at merd the and is all said in port to unat in t
# ----
# iter 5900, loss: 51.832573
# ----
#  said; thor then for tots fon indalli theif of kivhires man thim); ther of fecery, Jrdant, the cros go crilof, and cath the the mofe, keof heot cive aof foud weverr; whasiiste faray fftwot and the giot
# ----
# iter 6000, loss: 51.864080
# ----
#  omess: endhist boul hiabilles, asd beer stipbin ?randel ang so Chat auceds of ?o retay bem'ss, bin whiclilt s-pharthay ald aad at themm, pos to githiwitinsn'W aidion to mote of as abe yece said, of Jo
# ----
# iter 6100, loss: 51.898416
# ----
#  sich wrorty Gacens the grewy whi of be wanngnsecats, aid thithe hats of Hom the mamoy es the i Toredth-repig mestur, thit (pralh Nasp of mavere how wirqh, mabt in Toe Lort the ne the hills trecher saa
# ----
# iter 6200, loss: 51.794168
# ----
#  es goor thit is neresicterecther ener at ; of He eno; tham ora, "A ferleraich, ho rhorre Heins, in rabbe Aghe to momtek, chine worl word be iss haid lifed"d, Nate "Be, whe day a m Got winen, they casc
# ----
# iter 6300, loss: 51.449723
# ----
#   paler Afcuiseth, a los caraune pramen-; and say, "He the ffenchy the like thy eand to ceablete naed an geary ksouo of to wiof thingeacisne therr thene words the of to und an ane thouns gait be destin
# ----
# iter 6400, loss: 51.346396
# ----
#  ro binfins, jo Thou"G crese Is nod mald unid bygaitis sehta, "Yy Dom efese: hishe'. forll Nice ; Thound, to Tove dliegce tofay, "As is herabuith is apcues?, the say eounte sine hreange thit wimpes on
# ----
# iter 6500, loss: 51.106800
# ----
#   giverah, and"."
#
# Jrore the of ao seld's, at bin, who as yor the a; now froe mans, as wigg and inchim of hirki his the gwond to said, "Rathicer; sagd to to hom the sayl but of Acrer, shy epbuls be the
# ----
# iter 6600, loss: 51.029813
# ----
#   'Fedn)'. ; Ulid, Rable faslengros thas is saal qulrer sath, of Toresas with in whler a has be hy chepar..
#
# Rabblon is it andesghon ickifgue therass habkit spotoa."
#
# Rabb sretunge'. the gre gifdare pr
# ----
# iter 6700, loss: 50.724781
# ----
#  'Ho t iclith apludh sait, hior.'
#
# Rye aa hearrig, "Rabl; 'An wofal theeste; fore hit inaty hof of pof is trevy (t ind wite fho cHeen told 'fon stiji fort of she Ton woortezlabeod thane to mon thathils
# ----
# iter 6800, loss: 50.645687
# ----
#  the beven wisf sas ofr'a stukt leakn, and spiyen it tey of amitint be and'."
#
# Rall iva wise in talnh to thy hilzoy hast if comcilnh a, ta protren; dor with yond his thou that in wos corr hron it who n
# ----
# iter 6900, loss: 50.229539
# ----
#  Lid han one wreres that thi is dathere houes sfont be aran of the wille Nas got winc word houknt to phere ther what denare? Methes the Aleng Ore herers . Torrnd to um, gor the eishurman coned and in w
# ----
# iter 7000, loss: 50.361843
# ----
#  ot of to said , and here ; bove iss proverth taren me snokf s'ane ankesnonsonser on ezaltic, "A grecsorgr cogaod in arll alt us thelf ast the dy sabinpe saidg ther ones and oh- of the dime sar ofs tho
# ----
# iter 7100, loss: 50.613751
# ----
#  vey hand; "sat fele niSuytes a foreccoucins, i hasay of pis neapchot in of hide gos to wor-d, hait thouf, fith leakh, 'He thine is nofersors olrcave ing , sithefealsss he whe saich Oner int recend is
# ----
# iter 7200, loss: 50.349573
# ----
#   thann in is eves in thind it it is sistin; and mexe dis deere sind Touthint whidnd hacziney regse a be theu thard orn fun A:, wo will hise tor orss th whare one shams lamaus, an ofon a hous, hio dton
# ----
# iter 7300, loss: 50.324929
# ----
#  ure is a (omrees, falbig said, sJas is for what the whes of gewyideds thingen on that mor dusins of judty nor the funoor of scucupno? Gnor the no thet Gakr and eing fof inarrt ull thiters ot lisved bo
# ----
# iter 7400, loss: 50.449958
# ----
#  ceveid qoors) ye to bite wore hin he smanhsth of the cucath a woorgsed Hese dive the Aid may Sis es of", "Ably to wild leace a Doves not sols ful whisce, ans ratk theer ; thrye wies reot and frorcaid,
# ----
# iter 7500, loss: 50.467090
# ----
#  d to sadnep, anh vonge wheed ras erisgend the Govyt in got of Aid, "Eveid of him delittelm thanasty fineseser on of bive to Ecoror wivei ale.
#
# Hot thast, ald for of of blounet, ouns Orlerans bener the
# ----
# iter 7600, loss: 50.459852
# ----
#  s; hai if wrich, sittin shove ofr hor whole llyon Pes said oune, ; hon ary ard in say , Rabbi Nor tcom; end of Elieait of coud bedespaln, canl but Sambursas stis, "An- Whe prall;cels ase of Tor thim d
# ----
# iter 7700, loss: 50.311076
# ----
#   hicrear the and to As thes tam mad co whisunged woade." Rabbe ingr ind said, "Tondese thit loukhto they lall thy ard thrint bun hith ; Irarim.
#
# Arlt as of resad tilite".
#
# Rabbi Eleape, of AfssersriNe
# ----
# iter 7800, loss: 49.996285
# ----
#   aTe Pulide perers yedeeantins; "Preade ecowhafo the who fon the a ature, the poad, of Jutcino: forathint it imeth in be Dosror ipthes; thea a kave sat meuf the astal, a hisgone onTwilonel seitht fore
# ----
# iter 7900, loss: 49.894247
# ----
#  stet ; Aidyg, his domeres's scaldoy i pime thinnoffite be the han of theed be hockid hedne It thullin.
#
# Theuss the seedt engerech ind ladir thaman thet manded the Tord.'
#
# Hloul sele the Daskes, to le
# ----
# iter 8000, loss: 49.729595
# ----
#   onen is hes; wive in gine luta thin ant u avebent to sid), '
# fraites in on , the ppreengs ie gherone; noo oud lnove of leme Goti wrors thin ofred for an afe grolly'"s this ; the perot wircof wie nove
# ----
# iter 8100, loss: 49.598232
# ----
#  , 'He ememe owher, shete hallre, elemers hat is wrosdrothanal sist thou recmors is yore. Ktordu lysprer mande at the do Ton thare haid tha A , "AWd norst of the Lore the ruar, anged i chas wild man to
# ----
# iter 8200, loss: 49.447985
# ----
#  s hald lilether hin geapuse That sande, be deanth and ound, be nalt whes who himed sand ulles balde a hin as ciseon hy plofthon a dud them sand.
#
# Rakbas noggel; enene gveons prealnen , ande woad furhe
# ----
# iter 8300, loss: 49.330138
# ----
#  win thy in will ned the ceabbe be poulw; of Spmundrabbiss haid, "Im (theu of he wilk, "Lose aid min nod ruth bat il cenks, and ibuizalfoa wion sads, "I marm and a Lofesss of and owa loke ander the wir
# ----
# iter 8400, loss: 49.007184
# ----
#  prelprone store to cam hpese pafwine t am reater, for the sader oud a wack nource the h ike hikabe hawims cyanged to nearnttuandod eraceed cisherecherson tun trake an mlye balleg on wit nede nored the
# ----
# iter 8500, loss: 49.348578
# ----
#  he To nover old sand the saitotede to hom ingrye of pesthucter, ofssoud prisud for deiton, bushore buke forpclive ane note bes fose the hotings sot the hasaofe is co Torid, dIme he for nedar, to fich
# ----
# iter 8600, loss: 49.472235
# ----
#  the hising? 'Whand thin grorg, and gait mand is the wove of the will hin mallins fos the sikl hor gaid, "Tot theer antin, maneledigl of ca what tat in his the sange Dots ; preath, ou fles in fa-whaed
# ----
# iter 8700, loss: 49.222218
# ----
#  redile prich procew, ove ass of the yonser wold eptald said, "Besers oveel Sevegedh the liver and and mane? Ath ye tucl wrear ino the lim, of Hecusravenst it and who mom rys, dactichad, cale the mis u
# ----
# iter 8800, loss: 49.276496
# ----
#  in the said, "Tond and thy the fewten mand hice, Hemye no theurscqoss, soun, it in tutone, the agrent wofktid of what ffley bids oralli Jorh the hesst allicpithir , sarir, tat nown will mai , of he mo
# ----
# iter 8900, loss: 49.430898
# ----
#  ce? Whisne is thy gom; datty orid".
#
#
# Jote a unded no matid, whacy nos geraie not mace but ame thend iud nou e ane goene de threlh of who tuem) thin ath thitid soncogs, "I seyd 'Maled forl as hist the
# ----
# iter 9000, loss: 49.408739
# ----
#   said, "Ele thit in for thece sello even wis therday it mroum, wreceahe scoron to therutainay, sor thy it wort ogrty, dey of Jlound the madty He whot ongen said pvymored llurw, all tared other to beis
# ----
# iter 9100, loss: 49.467562
# ----
#   it ushed the is ungers, aacherth, comes sor man seablite"ts the Hisiten, "I "He thoulabe forathe srofahem ersi(caidilgis is yeess is wince pos to novey, no more'".
#
# He acclerge wowss, "Do eleawters t
# ----
# iter 9200, loss: 49.164889
# ----
#  bby therulhbf ald thin tof thiar yeay in duard, beneg thoussant and ou themathe) thyt to Meadnott will thou, "Eve hom whom the wornaintari gxam, thecy lnon; lat: and mamist, (then tee oux fiel, to tar
# ----
# iter 9300, loss: 48.901475
# ----
#  ll retumeo, rise? jud wale lan, caman all a levee who docseits fit iss the comoc the And les anthin, on the whan hy who how hay the, thees caele thyt savbi sond it be Toral fhesay of soke souen dety .
# ----
# iter 9400, loss: 48.755907
# ----
#  rim, frrot sayd and coshim fesive efored wornen d wasce naunhe the Mrared himan, the Dedomemo; the Torah the sou Juperdhenah, "He m(wate and and thous, hemertes an oke amaigh to ga mand of Toke hon st
# ----
# iter 9500, loss: 48.661887
# ----
#  He butian, awd apleous, score if lauln mare lraww mandepcora to shies, and eneevayedge ne Eovtrad ; ho dave not is 'The will.
#
# Hevend in trand) of threl anl pracl upverdrede miokg yom no st us, a
# do t
# ----
# iter 9600, loss: 48.498925
# ----
#  , les fo haist ins's the sand, dis till in to souh hantive to sousd is theecen or".
#
# Thore, thet warah, .
# Teerh, yeer tith; the sont. That is tho farable'. Sus who moncon, pemaa; sand andes than, wind
# ----
# iter 9700, loss: 48.405062
# ----
#  a ceadstand fore shee Miset, in bumahit Beopnnt beelise, ald theuh the anrewe to cance of thabl, and the thad (the reccondom toll the sin for is ill nots opr say foranec.y Zathemon ; is hove Vovere si
# ----
# iter 9800, loss: 48.192849
# ----
#  nsste, thao fall of stiazirly that bea pullpe styine teive you thuce; mambere ath of dearee the pray, "?
# Rabbi n brpupnawe lege tuceyy shith; the yougs veterotiond, to re wiedtu, for. Whabks, if mis t
# ----
# iter 9900, loss: 48.030331
# ----
#  en; mex gewher the prelpet, whear apt hambi Enake? willud eofe sthar dramefon. Houteato le Hefgere ie starcobn) he mitud.'
#
# Red"".
#
# Rabbi hit but it be hevremtyd hat in thers son agson has lafth revek
# ----
# iter 10000, loss: 48.429818
# ----
#  alt fmacl fore tite (pew."
#
# Bese, covy to yeter, a Nipe oce the Hol thim, deart, ane the gored an ; to frowreth, the perliows Oh-sone in golcim, "Sossenae of of whenrsver? ; inot theur woffem, arl not
# ----
# iter 10100, loss: 48.377391
# ----
#  the rrogt, asd a kerpapalzent; the swis the hafeme ewasm, "
# Rales eongy himtspiigso wive chave a engceans thado Ton is thou bo the pis rrcovemy Why evin."
#
# Hemarah, as and thincene is the ploas-geica
# ----
# iter 10200, loss: 48.279033
# ----
#  owi theus fnomale histtaens thoules in to cos fa muist of and , acvye the myaxca, of hin thcinnd hers wig ise berol, of Juth) at thes paverfals of the uevenet, ant sauneanes, of mpalals Tar fton on of
# ----
# iter 10300, loss: 48.424785
# ----
#  , heplece it (gom and kprear the To cas , "I Neane sFawtfidsein; ard hot the mos the Nameng fowr, by thes Prownon, ato Ningmideson the resever in ers, everes, sthem, , the juch, lithods al fare be of
# ----
# iter 10400, loss: 48.468560
# ----
#  tufem, at the thingen not ferwibal) whom".
#
# Whow. Toram primithdy Priwuth bon be wont paoue Sichirestits for Srourls will and themer with malm, a them bn cike a forlved. Anid com thete seid; Hom chamt
# ----
# iter 10500, loss: 48.521714
# ----
#  eret will son of a desert anden not wind acle it forlor dife mintry, Tillad mare to The thers andeth wille; thou that worch (worlming him le crore thoures be precand sow the slave ired the and an ther
# ----
# iter 10600, loss: 48.463535
# ----
#  apmuride Iraoth of Elriup-, bof the Mouppytunse ; the sprlateis firek, man iltino."
#
# He dim laid, "A disath , cabbi Joeschis a saped m; shece in these is is angthaisty ann abbe im eabis, for in is the
# ----
# iter 10700, loss: 48.139915
# ----
#  on the gonors one of greakles nom Beade ior ; and whom and sarls chabb. Scos of , stoir thisting said, "S andertei: the whey thyy of Gusesst and of muisg. Jome nof , and Aly at the cecvered the stiulg
# ----
# iter 10800, loss: 48.008358
# ----
#  ing acked reckabu , of thige hime?"
# Ag of the as owh sabbe aprsangs dearate?"
#
# Rebbisligs now that ; sty woel coraf, for the fwakt won af ghord which Toresthers frow ; be Tor hime dich; thans bysthare
# ----
# iter 10900, loss: 47.865872
# ----
#  parly, say, A(d; the mudmoned thad 'Ovepa, that but in excumene, simtqasing's (be thres is to dellite vaid, "Do To the sarda".
#
# Rabit kaby drawnothel sheke the e, withela, whlar and thiss saykuled of
# ----
# iter 11000, loss: 47.902868
# ----
#  eth in cass sand wifk lestennegh worll demer the Asr mand practere: inon loure; by u mat."
#
# Rabm to sas fullnge-d, hinpge sand'?
#
# He now an in nawes hir his ded rarah; Kis satengsatisefmer, thie".
#
# He
# ----
# iter 11100, loss: 47.793569
# ----
#  ew a bleazul ; Gladky a be wort mteesh ith exve ofre to manles; the worde and butisn is or trane (of por sanbit bet hane rewphationes' ; recasce him."
#
# Ras aroer: that toud tay ; One, thendeastrah'wge
# ----
# iter 11200, loss: 47.774185
# ----
#  oul bot ri hiw rase fsaaver spuste oftriten thim thou thyeaitt bow mist of aed to so peis, "Kesel; to vat hy was theed tiln hamen of thomar. Whe receper: of gis coones to hosarfald to sastoth worl, th
# ----
# iter 11300, loss: 47.371989
# ----
#  emege the sIighir;ed of the pom to derpusceplour. Elecongethou h)mery the co Elese shoma noh, as it the Tolneks has nuth heysetho etay th ut aidg to , is said , Go blig-prount "? Rabbe kepth and the s
# ----
# iter 11400, loss: 47.458438
# ----
#  en ne worn the Cons mid sous of sacely eath of Jobgemor theunogion not himbition the dmanstins efcrat on engof in I creptory beme of that fonss the them; not our, the agher re it to the gino by ke the
# ----
# iter 11500, loss: 47.864818
# ----
#   ail the comesed fo hee snanon fithy of Torshe to psyad, oWhitinedt thisand wacs hathoh for faorged forar saycy han intida , who woothepted quepolyt pearlinnon thay hir the earavere the Lond ; the thy
# ----
# iter 11600, loss: 47.719997
# ----
#   the sainWad parinl spire forntnous ; hiu live and thenom Got thuil) thou nourabu hass yor upong loccied ith teace, a ghaves word yereah the Hed. The saved forfet be hawelh of toal in wronth one scish
# ----
# iter 11700, loss: 47.718546
# ----
#  y is putand anu sinly nomof the llai(, Jovint in at ppotlas eastaity ith, Ant thamoms on (the of gone gisturtferly, dunzay thet binged quiglibverot thand at to Theren mar iss the Torre', Hin said, "Th
# ----
# iter 11800, loss: 47.933916
# ----
#  , of Be there."
#
# Theing (to not of of" Sham (the reverrond t yesgeclin bem."
#
# Rabe and cofintese thern an) fithpeyt rithek, dom saing, of Jome?""
#
# Rabbi.
#
# Tfors the allunsen thon of one, by Ais piute
# ----
# iter 11900, loss: 47.918886
# ----
#  n turtes wide in theer thouy (a winl ther of (no arecelf, tresred".
#
# He) asd all lemenged and lemsers therasat ifwilen thy mon the bjeith ours thy meverro of coavud, Rald.
#
#
# RRee the cenwhiraheve for
# ----
# iter 12000, loss: 47.998247
# ----
#  n fye a grochact athound ; ewe tecwinly lom our wancen of slathrt-atever thinn, the mam. Dich it ; whey mane a racrilico? Ie firegh, so thit trase puase, wror that hike thim conlen the no fruceurnchy,
# ----
# iter 12100, loss: 47.837351
# ----
#  , "Whon of tinir comed, ne altef sues domon sedser exacter orath, the Toratine thee den of for sont ceibifip, the pract he mate of min eave the for thy Ton thesine, and the ant ol wath hime the Sishou
# ----
# iter 12200, loss: 47.467641
# ----
#  hy macte, He ait of whow is gefinginge thase be was unsane that of thous, they say and, wrve it prawged it of Scay comees to be who whow the scolelrnd amin of dalge? ; thod"P ow the Luthired, and he d
# ----
# iter 12300, loss: 47.382881
# ----
#  se, Monaringe stistings of goks in ereee has of seeah (s scate'.
#
# He bon of aperstis with Hewithil hee, thour said bueat said, "And weid, "Whana base the hamenl yous, enle, of nabu give be of and nece
# ----
# iter 12400, loss: 47.268468
# ----
#  erst for in the pofrfife".
# Jule at ulltwheas thy Syreart , the muven to Meawel the margon Vaver nof Gode to wams of come bemerere theent in a ware io shome thin thourdeior ing ; orr,d though ohe ne t
# ----
# iter 12500, loss: 47.256486
# ----
#   mane he wharnes. lid saic, Came fissit the Thererenchosed ho drbbit mane it wirlives juppile thow to seale enae to a and wit ffon theron (the hen memen'm yo then To lada; and forchene aat ther
# "Jy th
# ----
# iter 12600, loss: 47.067751
# ----
#  ., "Galn, of 'uschewi; sall hayst un foret mexozive in thamabnisghen, ne Hile of jnrele to gow) soul of Swofeus noud bgkerutying the thefer call piped but, Ind to Tors the mouch, these said uplachas,i
# ----
# iter 12700, loss: 47.001597
# ----
#  ile in hive theas he therd in lame ceeth man (of Nar pracle ie bmey tit; dy lowoe of las it uancon me kentur nomsonand, mayg thest ofron it meraou the t it the pers ave and of no sloed of Are of Ta wo
# ----
# iter 12800, loss: 46.679672
# ----
#  afluin: beneda, and to whot is to melm, and tingsan the To horlen, the puchasfyed wirk." Tabbt hasate is Hessers; wroth'; fualet, thy beakt boses his thitit of tucoun torat wrentoot berer, houtions be
# ----
# iter 12900, loss: 46.923434
# ----
#   noch abun of Joshey owhrsth fol lishind thy torah, and, an Heistigh the word coslaks a datelit. Tain of sey notansty theth ; fonied, que peadsensasas; and the tithaned creabit hiverters-fexrouy""
#
# Bi
# ----
# iter 13000, loss: 47.249036
# ----
#
# Rachar the mid inah scaze deatce trat to them the comad, coo one say
# Be acpoke big of Agreaig peitis to this is isterssrokr the jud; ysty : Jat lrgave, frasemegald of gis Oye: to the a liontint one
# ----
# iter 13100, loss: 47.002747
# ----
#  rle thear he waod amters lacker, Ais shaud the wofgs. Whoverges deserens isveve the juthon the wisud the forleak, unhingonor and I hass ans, ffri: m)ters and maddread pukstharss for of Juseent who Tas
# ----
# iter 13200, loss: 47.002727
# ----
#  e of repeaeve so said, "Wham, and he at is it conar is nushun shan (or the how erouly age"y. Nistwis ast lecdengerd thots and and in fof to aid for nount inty thim Pettt (orl is of He soun these. Se w
# ----
# iter 13300, loss: 47.195465
# ----
#  t of Heard, the monessed youngamer sands ever intresty of Elinile ins ore say ppiver; ana, lende Seavering."
#
# Sitfer of the worbl feated alll ferint , bum it meraked is fon of say , Hish engy the Tore
# ----
# iter 13400, loss: 47.261131
# ----
#   myeldesst ore by not aistind, age wish learatess of gutent. Be ae ngattint is ord miscliviols tiren n the used the lears to ste whom'
# , ar ofrt".
#
# Rabbi I darling ; a laveras be thry, qun-hwill watwi
# ----
# iter 13500, loss: 47.314989
# ----
#  erger at hile is ind lis is ind thou thor to sand do hor othurln, mpili loshim, on an upersar, anded the morin-s of the the lige of Beapry to he with to eaclit.s barned will south sho g; ascone harits
# ----
# iter 13600, loss: 47.005780
# ----
#  ot the be uel that an) ttuchinlcabir thie of Is and and the doistis doucit the dione blented anned in thees, he who Elases thy is of mil the e pgarign; the ring alis diclupte grice, iou the heser , th
# ----
# iter 13700, loss: 46.748620
# ----
#  Toel wond as home's is of thema litkey with wan han-san aAle".
#
# Rabbi Dea lose world, at ; Teo reaved to pecrualveke. Torah, the who will souple as is to Noth, end the urd thim the bade hat the sore t
# ----
# iter 13800, loss: 46.648529
# ----
#  He will bup with I onu be said, "Whad Iy and the menghere le, d, at mall , and who desusse of saws in and seatuin; his stuch not hiska, hand, ehames wild All-widse bros no stye then thyer ne shengusti
# ----
# iter 13900, loss: 46.567903
# ----
#  wor chigh'a frow iom mithore ulchyendot our sanded in ther, he sing)a, "Jedprezare of Shey then to sin, at frow plover, is card abbey at is a darihed'. Nuthahle rever tukn kecend Liclintosbuse mariwe
# ----
# iter 14000, loss: 46.394391
# ----
#  haap the jud; bullnare? Whachers mhe hatsen of, fropret it is ig hirssam, 'To ty wonld, Jove an hangegh epipe cail ; ham excreanne of Susand wams onets coowof in the whosthedses for ant, "Is the perpi
# ----
# iter 14100, loss: 46.392385
# ----
#  y to upite y, and the the said, "He wond of stuper witho abdreess has not hees with Tool for to Lither, in thang thoust be mon acler comones ander ne cenenoal is lecroge said, "Wom alle no the Dones E
# ----
# iter 14200, loss: 46.289024
# ----
#  din' (cow who mine , on heas aptttin ; be Hiper, and be has tat sticles, ford is jude to and foren: urce tit sporid, be."
#
# Sin of thine".
#
# Rabbi Chamal the cus on: dreas men ofonn wikt fo in the of He
# ----
# iter 14300, loss: 46.058689
# ----
#  e for noke aIs the hof on at benoth one of Sar to hadgones, thy ceabu thes be tith he ash and wordd (un owi Edeee it the at sece, the the theg the remwie of Hip mer, ant the He ming the cone ceansen T
# ----
# iter 14400, loss: 46.478306
# ----
#  s thif erone showtta yace paptrount the is and the yioks thingehterssy offersnat labk fofor himtt of the ringens em'. Jore no Dee nougtito averfority renstive berain froce worlitioto sioz nengoy uled
# ----
# iter 14500, loss: 46.599038
# ----
#  is sricake nou sand ans is ale thoud the hing , a wild Ie ofed is or to nouvelllidgy terer to hip is icignos owden say, "I him neussed as ofd the sceurtes caspindenstfer thou wort a , deOnth, bulfite"
# ----
# iter 14600, loss: 46.429925
# ----
#  o achint of the coved a lom; "Be recrews the, distomoy witt it to ane and pare ay the the Sis the Sealis oh the for fon in the redy kine the what is the Racher as a buy ast to prill whet is thass no c
# ----
# iter 14700, loss: 46.439858
# ----
#  ng in a mert, thathtssandoresprlalk, nebre prom ; heuse, Lorls wioj ass aprat of Coud aid he usnamxon se-pelrais of f wrueg or comsoof ford, Here say of the sion gomamy, he whisgredste. Bet , men arvi
# ----
# iter 14800, loss: 46.604990
# ----
#  a gacars fires wibbn his ney ; whey in kent he aisg ecevend.
#
# All from tabelns ano enesg the cortulvahan, "' Ifit whome thils will angon ceedse, , como, Elot ducly and aud ; nonnglin stust ait the mup
# ----
# iter 14900, loss: 46.663624
# ----
#  brened ceothin thel" by whond thy and s agah. Whilgen, widar at watt of the not the leas,-drime, crcechees souss fforsts inolh: ; evere yearh, thren, crechatind ; a magaracher for to sin saralchin ; m
# ----
# iter 15000, loss: 46.707120
# ----
#  as and eves in for ave am'. Lord hase o) Zspaid, (abe, the for tha the the the bif Arewcibm, of He mais, ghomad, ame to endithinon toratmas ort at ore of usaty wofd "Bel, ofro dregturs and the diven ;
# ----
# iter 15100, loss: 46.359799
# ----
#   fwase them to recusen foust in thy diwasionas nongs be now haupt, and Jowis goftere not mon ince blith the cracestho es or-tande of whe theured not is a gis asce ancond, and preis, as ant. Eneson the
# ----
# iter 15200, loss: 46.224817
# ----
#  , "Gors accigsedn hessen, and ity there's upichar-sa, the pow uplayst stain as of Rataid the sthin higid, they boch Is is in in thyene ; seldam, sand hiperel the m, shewn eow anmerf? Elien- lackes, ag
# ----
# iter 15300, loss: 46.099694
# ----
#  "Who criskabis a porels nof in Sciiguteon vatssated ony The saipMe, aid thous dowa pfirengs, apodis who Nhaid, "I the lede fefwans the weay sang, and his thou a maingedustythirgcipye withy sturass as
# ----
# iter 15400, loss: 46.173972
# ----
#  hyer balirfeavel. morongs of Ast ive is a o han fulinge thes inl ther it ie thee fora shen have ine wiskid themere thy thy lry tarlus in the The souns wrive price in ou) be ast amibr elyar the Ale fof
# ----
# iter 15500, loss: 46.006456
# ----
#  es is en ward not hale sins th. Seand scayp the soue jusged hin who 'He receah cons trenterurablain is or) be comcour to sard, the prezered, und ave will lent mestiotste'.s of saylike and whom".
#
# Jown
# ----
# iter 15600, loss: 45.989889
# ----
#   the htrean dewulle drowes the mandurnen, sond tratind the to pelihters is arg fours be coraring and a one to eadelos of Thiel fameteca lecuse noutis fof to said) is the wive ais thit it be Alnye noon
# ----
# iter 15700, loss: 45.806920
# ----
#  able he deard the go»m and budirgh watde than to thane busas they , "., Rabbi Jodabe, nom what lomand sanle?"
#
# Rabbe bemar for wall trensan, bks is the Beased ; poer; he arle, of Kuld isti forts is to
# ----
# iter 15800, loss: 45.771445
# ----
#  hen ; with to matin on word it vimegblide lacky; fif the difee one fve fe prase antielr; saok thour epens wat ist mell tho neazers, and be Ner-woh the hos in the wiss ens iom the pis the thousty it ,
# ----
# iter 15900, loss: 46.226345
# ----
#  his; dorstor fos the he feot nevar of is the Torasaine; nture thete on all. Buttur;, young wat of that wase disters the himanhe serile. Bee othe world to ghaid, "Do Hiabith are thee aivad thays Whisce
# ----
# iter 16000, loss: 46.211708
# ----
#  hepveres an with amali fos om thou the spilick foles Bofwingras in tunu thouls"s a ferguty fon histo aed erging love agonn the venry a daried is thoust be ceazkee?, ; a and suavels is tabn? Bolah. The
# ----
# iter 16100, loss: 46.186185
# ----
#  avin maysapie, and hat ilf ho atary remspetser thofy the im the Toreftailf givend to torah, one aEsthastiound foudged".
#
# He fecrod word ne fritho for anturs, and dor evrumafilahafnecore avered eid fom
# ----
# iter 16200, loss: 46.400094
# ----
#   ackicthett fiblling habby iust ; says, saich enge, audes an ibittmant, geverait at in whibigh hirrem, promatiname torbit Preaty,  Haser bereron".
#
# Sheston as elepes us to thou canttstue saad realhise
# ----
# iter 16300, loss: 46.388970
# ----
#   bot nos, af prowo I seae; sand futy hitt ie Sa foferssent at in lutyoow hait puarss int one to lom there ans; reare axtilficldilt an in kroch, attunes no Thoue nod bat for thendever sis (pera feighy
# ----
# iter 16400, loss: 46.466935
# ----
#  ea, and oveils, tome alccaricat-timelve (an they hin Ged m, "worlmen of the Tore Jovrie the said, "Wabe, thone tran yeow; aCdem lombrownee, , anged treives treid, "Lele ming tham the pontr?, gike a gh
# ----
# iter 16500, loss: 46.299094
# ----
#   s as uid of the aclives of no Elasee whiw thom buceah, ford, shacieschea, kook gros inte man une an the your fort has and way."
#
# Jeged and am iabio him ios be dare loulh cain canilexlus be meracfaer
# ----
# iter 16600, loss: 45.926448
# ----
#  ut is taystens on Bon sty, and thes fearty and recreath and will the exsucMansen ast it , ancoored said, "Be hame, yeass aveneaine; out is the dofery the his it for be Heanty ert furfiee of this dears
# ----
# iter 16700, loss: 45.873777
# ----
#   thif nonot be and andef tomath that is Chame the for the , anond.
#
# The with man to peary arratinne stigh ; haup to whoregss forp; wher: ded of Simed ; othan is placl Peala, and , of Belay in they fau
# ----
# iter 16800, loss: 45.660391
# ----
#   "Be a disy uttheah the that itees be deceny ist it wastire; wokld; som pulivinl will. Torself, wische goos the Heall thise -uazaraba thome roulvitel , of ssas asafegfoch his ou the the cood bourd him
# ----
# iter 16900, loss: 45.716078
# ----
#  e uathie is remer or the uncall-prewcild be piver."
#
# Rabbe mame orthenst the hee farl the Torah."
#
# Rabblidem, he didora Gode ofrer whis saige. ; Ind thin he who spond said, 'He rcverer, say y watasenf
# ----
# iter 17000, loss: 45.578550
# ----
#  s the Said, witlat (sor wans the forste on co juditem; sow fiet be sald the honer, brilr thered ; the mathius to ther' nokes and lyt wholbult a lot it a chansazarirs on'."
# Rayps the difpone I nowa way
# ----
# iter 17100, loss: 45.566173
# ----
#   frow not ho the kuplenst be gill stharhtto ander the "I Torsbe they the brike whe puccerinad es derigh, and these the eon spive woon".
#
# Rabbor a monaid bit, elion orenh freamen ie silnen thes , of ar
# ----
# iter 17200, loss: 45.194490
# ----
#   nokne, to willalf) Ond ontsares: stutame mas nerute Isalloexsting a spimengpiveke an to be doot ofh the was hast fratatly whel torih, torl him nowh? Wamat, "Whom divels. Tha puretheo regroof in thase
# ----
# iter 17300, loss: 45.378355
# ----
#  ace the Cheptunt tousomudites por andors, and word, nnorhe undor; owh ind groed, thath wioniof; and be tis, appainge besoith; and a dares of Hirzar find of the to Neoush"
#
# Eid thin desees us thitt of
# ----
# iter 17400, loss: 45.830956
# ----
#   spraithed no thlamawiod parl firespond ithound: aid.
#
# SRabbe if keyrudive thous, EGesne.
#
# WRabig, tarm aby, say, "Ifsaid, "Tht ceaping who ney, He wibl aming bulato mene he ale foxpong it ther"s it k
# ----
# iter 17500, loss: 45.726583
# ----
#  or coud whinated sand ofthat on'"
#
# Rabbe the grovinl cones; the who uutichels a fer a firfole fof the son of the shis wif-ppeaich apsafevthot ne says , the Neage of flot of Eleid; melcreary tenur, shi
# ----
# iter 17600, loss: 45.678097
# ----
#  enceft sinorabi ghilyth the des igqtilte'. Wreesand not ino repslid, whit fiscking roly enro)e "What lavir wen the reesa, a cavery or soon, at ceonse.'
#
# Be aseg ; the give in Bear plom, it who hine th
# ----
# iter 17700, loss: 45.932478
# ----
#  in begreivirnder, (he eing eifmanl with the not to judnoont fire them nouMwisne ind dessevethen whi the Tore pona, "Ufutanosth (foust.bu sinen of astared the fut in whicberot, to Toraing and thou hage
# ----
# iter 17800, loss: 45.909198
# ----
#   mecely igh no say; busn' Jolt of a kofing the myorved tratht is it , that be avermaid, abe bor low his theey earcisa-pemang tat he coil every decerna word, a quimaved (tho fomay, the be uponst (the w
# ----
# iter 17900, loss: 45.959277
# ----
#   nond pumuney who dyegroce, and ; a Nachur, and the ; and Tores forod ; the mach of thewe".
# Bet berared to fos apeah."
#
# Jxgorion po cole por asedmon berrerinl ther ane thy Nas recend, thom thoume (noc
# ----
# iter 18000, loss: 45.778361
# ----
#  ron tsarialy, hom the To Driele ; turad, "Who Torah".
#
# RRabi they-goshar sand, butarit. Jofe simseon thin, heare grocol for of thay thing fruded whos lyrahe of shace of Aive titaing."
#
# Hemand withed ,
# ----
# iter 18100, loss: 45.448173
# ----
#  g al-tikttsathe) it to say tat it iA ta be Je was a gave frive thaal abdueah thabnae onon fos of ttous'. SEkefceidgromad the meals at And lepoles ane the Torging to gaclionu the wiltipad andel in thet
# ----
# iter 18200, loss: 45.354331
# ----
#  . Tort tase thine to and Gom Hymenthiath'. Ard de sed. (Rabbi Jachem ecewsea wame fulus; 'words in thy gradman, a death soo is sin hivly and the thou pever, ay "Tegtur shale of Name ; theed haid astle
# ----
# iter 18300, loss: 45.239854
# ----
#  leienfom thischou anouls ind yoms and He gove, "Beraiter; them upon enalr and and grive, whod is vilen. Aen recerfusfole chame gevei the mail ascaid bllingd, soo ne may, "Whess; a liching of Juce your
# ----
# iter 18400, loss: 45.227959
# ----
#  elf whtem, in the sturune son, and wisd tor Gudis, a descisad Ir' us bey, "Prarting mung relan'. Is sertcear say af at ale all oust is oud busurldied thans of they is neron , and hesplessly ay dersit
# ----
# iter 18500, loss: 45.107293
# ----
#   he counst the megers he witfans, he ondom, and is nom Ta lifesassinndelin fa wasliknd hes eibnsor to Jodist fonelked is is , and Shike thes overest (ulro fithine "A pecreite, ingsinno not fochy amdsa
# ----
# iter 18600, loss: 45.070970
# ----
#  har is game ".
#
# Ho coee hom han end of Juce is junt and Begline is soro nor wood har the juds bertinn-iss thes; and that to with He who eunthed to Mimai, mor the worly said, "A partin hearbee the the
# ----
# iter 18700, loss: 44.748638
# ----
#   the woxd to in prestar It arawiot merln nawor sin, And them the Jedowi Jabal sand".
#
# Ereave the Lefongaind Icard ard hoprem.
#
# Lecard plaich be have the jud full upon , himet, and teat and the ham, an
# ----
# iter 18800, loss: 45.071502
# ----
#  er unheintem, his to iG thariod ang the malceds nots uiting-tints to sackicald the man ures oveos torlmincfire nactere the lall to gis kenot an anteer tile fousty manned tarne." Scjonge was prose to m
# ----
# iter 18900, loss: 45.394482
# ----
#  te a, gpupry: ho plovinn wits worls, the Jlisives on everecion of Award deate himens the gfone thate: thistore mwow the men nabad a pe upert; to from beeors anf wase." The agce-sppichash: as is a ceid
# ----
# iter 19000, loss: 45.206011
# ----
#  n.
#
# An of coulu, eve wort ; will be everts, but: and Beavejt comen ofons exacrures, and hake mancked and becerse tat im ca wisad fof llzase ins ins-the prain; and kemqearive unt ane upoulion, aud it c
# ----
# iter 19100, loss: 45.234858
# ----
#  esude" mat in otherine, reverm, fearf"s hemtenseghyer, this (and full stidge, (apleratived, the enenen (ore grous pors bet."
#
# The mevers the said, )ho staring bos the worch, and the ity storefe the Ta
# ----
# iter 19200, loss: 45.443656
# ----
#  rrappousase men, por goll to no thea Sisang to gimat nochur of scose will . trow I hame ance, hin mine one Nectesed and their int wigles is Piftund, the ream; ; andurlfes theer ercat. Lhishun ; and th
# ----
# iter 19300, loss: 45.505168
# ----
#  pricrasevee to in ind the dighuns on that weresten a theer for the rongatety, a dealls in is to cans pecrumer to dinlen, the meman in uth wither, of drom hin ponee sing thing be taicwy an the Torah, a
# ----
# iter 19400, loss: 45.600177
# ----
#  e llesmoncela; thy il plycounn whecs and thyud aspene, for thimers profus of Nasteets of A pelludite thy learbwikest, of a Jearth thou; Fonh of Eleaze mepero; whit be droh wicem; "Tud the mon the exot
# ----
# iter 19500, loss: 45.173813
# ----
#  nd , frosh thy coked the flow thit in thicigund ungimge; whaling to say, "Somlrudt ind the worldeds the in the ute"" franah of thy akt, Rabbi live on suit mad kith cone, said by ascure cickan of Jeary
# ----
# iter 19600, loss: 44.937286
# ----
#  ho mamets, the tuther, sing ingey of shise) the sow is is boul of nom the sthe sas. Tabk blous s) anee he paves of Lordh""
#
# Rabbi, and a gliptiot to dis rimeres, the ssed hiw then owdeste? He was, and
# ----
# iter 19700, loss: 44.887340
# ----
#  le not the for agrough wibling und in shably bow llides, exede, sreir, the-senced thou the say of , Torchobf the forl wist meh t ingraplisabah, , cith'. Allest not thece, in that in the wilkte, the th
# ----
# iter 19800, loss: 44.794333
# ----
# ...
# ----
# iter 40600, loss: 41.032912
# ----
#  ifgt ackensass bes homon me the nors, the fansull-lallstisdiun that he and themy ownicy; and whirupored warten with by thend be mang and worlsth yeasl is goon in the whathevem in the kede of the Lord
# ----
# iter 40700, loss: 41.070545
# ----
#  t (ta leus the recrupenting bive of thare""
# Thrure the sond eatiem, a his undest who beard of Toritit ion there eting and peracling oust is he cammed thabl gransen a quillen: your buting in the yon be
# ----
# iter 40800, loss: 40.856623
# ----
#  e words ofrure came One fighou, and Ableng ; querions of Abkidenth , what and?"
#
# Rabbi hougengels leceme the know from be berlus al whom glond".
#
# Rabbi Judge it the re worll."
#
# Rabbi C? leart, warth,
# ----
# iter 40900, loss: 41.209184
# ----
#   Abiffole that the sesy, the dewhread, all for the leup aceante. To neallt the fleived he whom alliwne-sed, and the fasiens our words the pecost with fike exee of in world) erowh tho ond in the piesti
# ----
# iter 41000, loss: 41.614588
# ----
#  ose: habbre am lawarers; enay, to upon) ; whis a cocl flullightuntigl? And that the despon of pixiceted that is spover , tithersettringpev; and imeerd a revesuth brest it ithounth of of Teesrich Sy pe
# ----
# iter 41100, loss: 41.403700
# ----
#  prilens , owa gavir toras for is mpleccear destiln; mabe to havighy for has caly of the can of Dis criped the ten dotherice thoues oh quiHixadils prachor, and wEovent a whom was cive buly cos when pra
# ----
# iter 41200, loss: 41.456644
# ----
#  ne ringly, rece pances if manded undet. He saic, "Thes me the govtues), thety roglich he of Teaters, that erake to upon in the plomorboad merers beturitescear necou, meese cass, quy (aft a pardiged th
# ----
# iter 41300, loss: 41.749759
# ----
#  doraty und but ang is is evers of dlowGed ben buidy".
#
# Rabbi Jochea coul; and Sume in but , the trince, the woknign convere) said the Naes fucens's apinge a Ko with cay nos in them; diezenthtrases; an
# ----
# iter 41400, loss: 41.735625
# ----
#  t nod of Torlire'; Andory, at a dawitlish his the sao them.'
#
# Ran..
#
# They, and J witsect; and freysan, is the rescumin; at wake a liols, bom nouln for of whomer coke grach a prortre to faou , ah bu sa
# ----
# iter 41500, loss: 41.871203
# ----
#   call thin goontingy are ofor man not abe bor are as ith thou he armit;""
#
# Rabbo "Beichult me I Huase are man the yewours oth ; chicroah of Heryed , upoured thil outh ir) who lif."
#
# Be sent ; the for
# ----
# iter 41600, loss: 41.413178
# ----
#   manporans yo To-prees , and thy seint, and the goith , de our for say for bot a Miffofint. Wharanen , the hosers ; on theu is nide, the drunscend pied frieahe is limene the urely, as or the well har
# ----
# iter 41700, loss: 41.266965
# ----
#  said, 'Ift an of thyilfole it rece, samen". Rabbi Josking in himsel; as a sevin for said, 'Fot the foon of Torah takine shakn son the distcom, the words; t astot theit (sorah son lich it astich says w
# ----
# iter 41800, loss: 41.132567
# ----
#  bi Elield levraty ago fighem, an whem sa, whuling trone makans ic, and to juds of Imalt; and word in exert woll be. he who that suit."
#
# Ram, llezlit'bibh, at the Lood who neenpur'. The diser".
#
# Rabbi
# ----
# iter 41900, loss: 41.033786
# ----
#  ary, shifele. Npithive thy eow all doe sard; Naw chos men of Gacrench: the poralinn". Ta singth is deen; whom and the Hore ther peskent lounscepegs is t tt anly'" nodge thes is who he upon (the paich
# ----
# iter 42000, loss: 40.896224
# ----
#  hy hourt. Sish was matharlid, whecray, worde ; a forst, his come is presese not thee ate arsel is thiny with; theer comen in trey, he ductiancese, who come theer thom in to lomef; and wink no dy, cral
# ----
# iter 42100, loss: 40.870098
# ----
#  l; aad".
#
# He shall, the ont, hay ((therion in theluslich ne Zensel."
#
# Rabbi Chom grich a mol eas as hay ourtneed it in the words, and the Suceat is goccumit on of be ore's for shainted, bussth of ast
# ----
# iter 42200, loss: 40.774653
# ----
#  ach rewmerkah.
#
# Rabbi Siclyseld to him the judged hon hous words not sow beuvat, and if the sentude anmers is it ittore, bree lefepenabm tom hachorese fot in the the saipso, ceather, ango forinvond th
# ----
# iter 42300, loss: 40.736261
# ----
#  hesh full thame there not ol Kane to the parch in the ruprurrion thom them".
#
# Theliof of cike not waich wecalf the manced the ruwded threet operong not and the duplouse over oftepoel creatahe meh, wab
# ----
# iter 42400, loss: 41.253956
# ----
#  e to came not is to cangon says, nobles by judreef of son dufael yerlite averylny, not year the leanovadid of gack besegersens gard upirg the sawl sons is the havert he rom, po the The resthi houghich
# ----
# iter 42500, loss: 41.374773
# ----
#  ath of the vore wort not the gon ; at is lomoring hore the rechousty ; a stue: himst aghiy not samdke men in the saind, hame cinks; wile, and in mann plich alid, has gis the who usen; hive engnea sund
# ----
# iter 42600, loss: 41.344984
# ----
#   reconfyan'. fith a speats no grovamersuntad no criilt , as on sons of Eazple the wiltigurs whosentsed wort the Torath, on the wilke ; good witheits wiok the ; andernes in ones in the your of expeasan
# ----
# iter 42700, loss: 41.449179
# ----
#  rure upols and nechis taor the didgen, the wike ont forid to powgrecr deabfing; and men".
# Be Awhlryed frear of the frear save) the divech evous, there frenteion world the fover. I of ; and was hiveg s
# ----
# iter 42800, loss: 41.524213
# ----
#  neelfi ; ast wise to the deatidil;t are not saich perermbote againth Tamaly a ore who com ffule asst, and plaovar, cove be used himsen, sape of Thisso. And but in thim and say, ; as of thy Torurmine-b
# ----
# iter 42900, loss: 41.639664
# ----
#  ees and at will thre on stict ther. Ne withir they mins thimenester, the stim, andored thee of Zas a wird within, that a weald a sahe, and wilt man, froan ana comsnioth the felarah, arcin, and wratwil
# ----
# iter 43000, loss: 41.558417
# ----
#  he he. pold it then whowerod upcand sind thou thee bis al shaid thy erfende, to Jish ofre ; Jeceice, ; quir sed dightua, thyo Shas, is unerfinceir to chat nat whost theed".
#
# He sees at wherse, theres
# ----
# iter 43100, loss: 41.179493
# ----
#  th, smadl ulled of Nugain in the lothelt and of said, 'One the sin fathat thelf withor. Jodown Lore astnouglsad feot in thry thyurs our groitaey and be says mait, "Jugh thy not in in sime sayd, 'Isals
# ----
# iter 43200, loss: 41.041805
# ----
#  fers of the Torah sous as is besfore mit in; haker yon of thome at stabis and the nor".
#
# Rabbi Eliileelon, dakale himsot, buce and thange they achures in Him thamar beserf, tha a tandt cromie chisst,
# ----
# iter 43300, loss: 40.842161
# ----
#  n mpicht foud be conen to a prilat, (houch, at scaye cand was insou not our it whose bemcelf ous bet who sune (as neines".
#
# Telll man wond alnorane thim kitter ararced? He aat the depmand".
#
# Wich well
# ----
# iter 43400, loss: 40.894579
# ----
#  upon is be for any of Bis jusgo said, 'He shardety alse the lat no e, his etrying to son urdether shallsted whreer is nour; upon as ove the Are whepplalfing inturas of Tor Jote, at resemadse in the li
# ----
# iter 43500, loss: 40.753711
# ----
#  ne".
#
# Huble them aness, and Alatult worln, ; He saidr". Abn hoven who om hamen) forbush exeetred'.
#
# Fresther to issom at toun, enfing: to say,""
# RRsu, is said, "Be soy the wordstty is a Ereat the efri
# ----
# iter 43600, loss: 40.742372
# ----
#  r not oven sealtmins of Arlich abnorbely, he with of his wisdaly".
#
# An gaos say".
#
# Rabbis ane paid will was ofted tare paons anses, his haraws aftuce in the leccasaitet, an them the mace was thenest t
# ----
# iter 43700, loss: 40.516271
# ----
#  ls ; bult emore; sheen grown though and dest, and berol.
#
# Thou comems, naus where in dime thou'. "Evient in tresten'. Andar noyt? Save.'
# Wheysed of Becrichir)shoufer to said, "As Chestre sake whecerti
# ----
# iter 43800, loss: 40.592284
# ----
#  g make of the died old for thine brablir to plain fols: demonen to ye qAack therred, anf; own war showo leosgion frand cool he sulmad bive of the muns fromong on and saypens erones plucebo batyer it w
# ----
# iter 43900, loss: 41.135005
# ----
#  waild the dousth of dorale the dofthathin cenevan: but is is is liscky is nongs is kink. Bambints, and grot to hartumars of his'".
#
# Thebn and to live; and the Nall ploverthe, have of whove ono thiec,
# ----
# iter 44000, loss: 41.147778
# ----
#  d, "He wilar , out bes thesemp, He zo whos him seitceas receah; NWarsteron; and men he weo seationty offmerf, enwone".
#
# Bet not bist; a will they of has domsullit not the Naal are fof abese insafis of
# ----
# iter 44100, loss: 41.112985
# ----
#  ty ven deesno of coe wildofid of that is said, "Leren, yeer que the conghowdathraisand to say fas ar his mude".
#
# Ekey undory of the ment, and , and a dow thee, be pimsthcupudccead be own his borah a q
# ----
# iter 44200, loss: 41.410407
# ----
#  ingegh calf end the wordie, ; in if sike."
#
# Ten of the suh, them.
#
# Thily drease to gieawiss and the in; of the encter in said, "Litselsst wickede sonah, a dish wecelfing ; Gud thingikees of triest in
# ----
# iter 44300, loss: 41.395577
# ----
#  e as meeved ingo butterrewnalades usestalt said, "Be knowly cook thou acour said, "The fron it in the phaish, the lith upe ol) fut of Jacare they an thim saibre thy ruster yams therresticy under, and
# ----
# iter 44400, loss: 41.507101
# ----
#  eass for the mole the resqueam Simenen".
#
# He under coaks evei, "Dount youversn; Suce, the son a do De thee. And dis; preadder nedo..
#
# He make the Priend, hayzan thrys a dedeverfiof that on ry of lave
# ----
# iter 44500, loss: 41.300365
# ----
#  wned wist in the ite as a mans to not acqy give the mansely) own from reasth theis wiste the eare sepperes of Rabbi Mouth of Nas neation for not bir sous has is is it im saycos yor evers to come thou
# ----
# iter 44600, loss: 40.993625
# ----
#  r the son (pcear they to say, "Beenege grupulf his thane yeer, thars thee thinet in his, art is singfole recelituring in thou the sert, he pears for thuy that and fokts in the butude thy cose tithint
# ----
# iter 44700, loss: 40.918721
# ----
#  ur." 'Yeah to de paysenenes hist a paray drople cand he unding, came to the fy Hepore to is the fewfear, sraid, "A grawsedgen, noth and Himbem"; the theip uplad in thy decee, be tanl can narecesved'.
# ----
# iter 44800, loss: 40.748057
# ----
#   man the sil Ipoury is las and reat that for the like exatneans our gas etine) a soid il it in the rood will ; (tho whoseverghine trou judgh, the stiloed to theme evines woid the cradwdirituled the Lo
# ----
# iter 44900, loss: 40.708056
# ----
#  ough at to say, , the parlle is in that was groath (shere, trarden, thatherath in sty, sredes is not heman (the Torld'; and knove eaese of the tey and fread be who gried caken, ; to can enenel; histo,
# ----
# iter 45000, loss: 40.500225
# ----
#   peoos, the saing them of said."
#
# Rabbi Zagaknishixs they be not evel thectiat forah, is a decciiod, a fiogh I thistir of but there olr fare sweid, "Is a sanjust in the ward maid, and tran bryer salg
# ----
# iter 45100, loss: 40.574789
# ----
#  ntely but quith? Sime, on say thee nod in a hos befor; he unding Sime that no reariren he woo the God in the. Moni: whice ast dracath drecredelt, be list since of the tim saok come ris that soid situ,
# ----
# iter 45200, loss: 40.324261
# ----
#  is a plovediou withibu? what and thet wilce losus in the son God bore of dumming persevert onr to they thing betoi dror toun thablilepren; lrol. He teich thi Abling thou , them s over-bunl ene twat he
# ----
# iter 45300, loss: 40.580599
# ----
#  f, thy reskndem fewsake frome of the world nour his peafue, ape the to said, "Anctyyan, that altisens shadurepentions theid and lecty techit fatromain sis."
#
# Jabbng ourts of Ise wheay mall weabory ant
# ----
# iter 45400, loss: 41.076544
# ----
#  er thy soutcemon ; thrilh is man sineviveminobs gand trester; to to userss: gas has knoch mes neai tond and said, "If dimey, and tey audghou onsenmer, and hin, be lagachile of to usst of for thover ya
# ----
# iter 45500, loss: 40.969193
# ----
#  tulevinney thes who sonth t a spowhe conit wabl cofpalitsesthirey)'.
#
# Tecisling is ass not the man, dorm.
#
# Rabbi gaves".
#
# Justured upo, no coule exceped of Zacuphaters those the he and tapad for the g
# ----
# iter 45600, loss: 40.938844
# ----
#   thysane minnth of Kera'mane of the Torah, on yeed (there ofe the courm, be ou gavesedgedy say Egichea his the crgsund the buty, he plecelfilithan ; and desedah. Whom a spipid, whit sparude, min son o
# ----
# iter 45700, loss: 41.212174
# ----
#  inger; and for ay ruptnest (on of hand Henan said, "He sanky ousen in it it is thince was cofaren fof teati dimuch Gas of the Sulrsand eigure alused thy begsed that the Torai ; owhere las ir) theigite
# ----
# iter 45800, loss: 41.226679
# ----
#  l of when be which men ittee driplidit to comas of the so words ereself all ingyed with Hucmys, "I poostit to can freote in the son it im; felioks a lick ; wrat is wherane: ; and reishening not thy no
# ----
# iter 45900, loss: 41.302905
# ----
#  s grace is asy there erspory sit him, miler, cut upon of the gristing, feans mover".
#
# Rabbbin".
#
# Rabble, themems, and the vind for habplide not thet yet whater of Himudres the son the greatbone fforui
# ----
# iter 46000, loss: 41.011492
# ----
#  o ran siony that in thal he usen theure". He withes ant year, and the with ins sach Torah, des am. Rabbi hactow noud, and evered the end leals and irawif; the farahs wratteiche thradion, the man ment
# ----
# iter 46100, loss: 40.814629
# ----
#  ve or thinge frown asg manrast nounf is thith be ever, and the word said,  Hen at isters plastluses couz, owhed they the bucke Ably the) Rall. studes stidly cameing prechay his by there and (oue, the
# ----
# iter 46200, loss: 40.696478
# ----
#  e ist ingosh abe ansols the Toly that of the ronelam ; theion; hot be meathel?""
# SqForn say thy Torid, and srein, inser thou and who dest noth hesticce forste'. AF. Raby hifgs of thy have of Dosty, bu
# ----
# iter 46300, loss: 40.548790
# ----
#  strinve , and sond hidh, ges when troules upon il.
#
# Sprowind; the sard mid, a harit, the ceccepreed lesers the ye sere eiple preided jude they world, reca wors ; Prapesth yok ourlsty it ore".
#
# Rabbi i
# ----
# iter 46400, loss: 40.443610
# ----
#  ser heyselt in the im sead word pifghende who a mat is and cabes one fill is what mone sither for hysen mannane in they mand shall in the work ; thisgested ar otory and the world; the Torah , be breig
# ----
# iter 46500, loss: 40.368384
# ----
#  o cresat of Hyemeod nol theshse; and said, "He unruseng.
#
# There , arcem the ratetais, an chen tither ; has deptoma. Bes amolf treat, Niil whas in is maccin, peraect."
#
# Rabbi Ecpich at not he wild forc
# ----
# iter 46600, loss: 40.359014
# ----
#   but it has homuth of The more the is al of bat not them'".
#
# He Hea, the slinn teulr pread whom swosl buso, sand he ce corlie which: and levers on of Rabbi Simed him one "He lestahe the yeats , heme n
# ----
# iter 46700, loss: 40.155083
# ----
#  r the melling that hawit that wite eve man tree, be ; Art that) wultull of Is and wit, for the Ho He who lears of Hom not perchan, flanke Elibll overs antidgedbeles it of to life erevness's an noor no
# ----
# iter 46800, loss: 40.591141
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-cc5bfc273acc> in <module>()
#      18
#      19     # forward seq_length characters through the net and fetch gradient
# ---> 20     loss, dWxh, dWhh, dWhy, dbh, dby, hprev = loss_function(inputs, targets, hprev)
#      21     smooth_loss = smooth_loss * 0.999 + loss * 0.001
#      22     if n % 100 == 0:
#
# <ipython-input-6-6944d53db68c> in loss_function(inputs, targets, hprev)
#      14         xs[t][inputs[t]] = 1
#      15         hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t - 1]) + bh)  # hidden state
# ---> 16         ys[t] = np.dot(Why, hs[t]) + by  # unnormalized log probabilities for next chars
#      17         ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t]))  # probabilities for next chars
#      18         loss += -np.log(ps[t][targets[t], 0])  # softmax (cross-entropy loss)
#
# KeyboardInterrupt:
